# %%
import pandas as pd
import numpy as np

#open('DATASET_1.xlsx','r').readlines()
#pd.read_excel('DATASET_1.xlsx', index_col=0)
open('DATASET_1.xlsx','r').readlines()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-bb7c19250225> in <module>()
#       4 #open('DATASET_1.xlsx','r').readlines()
#       5 #pd.read_excel('DATASET_1.xlsx', index_col=0)
# ----> 6 open('DATASET_1.xlsx','r').readlines()
#       7
#
# ~\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 639: character maps to <undefined>

# %%
import pandas as pd
import numpy as np
import os
import glob
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer


#ds1=pd.read_excel('DATASET_1.xlsx', index_col=0)
#ds1_subset=ds1[['Current Place','Future plan']]
#ds1_subset.head()
#location = ds1_subset.pivot_table(index=['Current Place'])
#location.head()
#ds1.describe()
#ds1.groupby('Current Place')
#ds1.dtypes
#ds1.hist()
#plt.show()
#print(ds1_subset)

#feature  extraction
#sample = ['Dania', 'Niketon']
#vec = CountVectorizer()
#X = vec.fit_transform(sample)
#print(X.toarray())
#feature_extraction = pd.DataFrame(X.toarray(), columns=vec.get_feature_names())
#print(feature_extraction)

path = os.getcwd()#################get all files in directory
files = os.listdir(path)
files_xls = [f for f in files if f[-4:] == 'xlsx']
#files_xls
finalds = pd.DataFrame()###init empty dataframe  

ds1=pd.read_excel('DATASET_1.xlsx', index_col=0)
ds2=pd.read_excel('DATASET_2.xlsx', index_col=0)
ds3=pd.read_excel('DATASET_3.xlsx', index_col=0)
ds4=pd.read_excel('DATASET_4.xlsx', index_col=0)
ds5=pd.read_excel('DATASET_5.xlsx', index_col=0)
ds6=pd.read_excel('DATASET_6.xlsx', index_col=0)
finalds=finalds.append(ds1)
finalds=finalds.append(ds2)
finalds
# Out:
#                Current Place        Unnamed: 1          Unnamed: 2  \
#  151340894.0             NaN               NaN                 NaN
#  151340897.0             NaN               NaN                 NaN
#  151340898.0             NaN               NaN                 NaN
#  151340900.0             NaN               NaN                 NaN
#  151340901.0             NaN               NaN                 NaN
#  151340902.0             NaN               NaN                 NaN
#  151340903.0             NaN               NaN                 NaN
#  151340904.0             NaN               NaN                 NaN
#  151340905.0             NaN               NaN                 NaN
#  151340906.0             NaN               NaN                 NaN
#  151340907.0             NaN               NaN                 NaN
#  151340909.0             NaN               NaN                 NaN
#  151340910.0             NaN               NaN                 NaN
# ...
